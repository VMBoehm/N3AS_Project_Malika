# %% [markdown]
# <a href="https://colab.research.google.com/github/VMBoehm/N3AS_Project_Malika/blob/main/TODAY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
from google.colab import drive
import os
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
#! ls ./drive/MyDrive/

# %%
import matplotlib.pyplot as plt

# %%
train_gen = keras.preprocessing.image_dataset_from_directory(
    './drive/MyDrive/z1',
    labels="inferred",
    label_mode="int",
    class_names=None,
    color_mode="grayscale",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True,
    seed=1534,
    validation_split=0.2,
    subset='training',
    interpolation="bilinear",
    follow_links=False
)

valid_gen = keras.preprocessing.image_dataset_from_directory(
    './drive/MyDrive/z1',
    labels="inferred",
    label_mode="int",
    class_names=None,
    color_mode="grayscale",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True,
    seed=1534,
    validation_split=0.2,
    subset='validation',
    interpolation="bilinear",
    follow_links=False
)
# Out:
# Found 730 files belonging to 2 classes.
# Using 584 files for training.
# Found 730 files belonging to 2 classes.
# Using 146 files for validation.

# %%
plt.imshow(np.squeeze(next(iter(valid_gen))[0][0]/255))

# %%
new_model = tf.keras.models.load_model('./drive/MyDrive/my_model')

# %%
# TASK: add validation data (https://keras.io/api/models/model_training_apis/)
new_model.fit(train_gen, epochs=3, validation_data=valid_gen)
# Out:
# Epoch 1/3
# 19/19 [==============================] - 20s 195ms/step - loss: 1.2443 - binary_accuracy: 0.6695 - val_loss: 2.8580e-04 - val_binary_accuracy: 1.0000
# Epoch 2/3
# 19/19 [==============================] - 1s 54ms/step - loss: 1.3920e-04 - binary_accuracy: 1.0000 - val_loss: 2.6360e-05 - val_binary_accuracy: 1.0000
# Epoch 3/3
# 19/19 [==============================] - 1s 56ms/step - loss: 3.3700e-05 - binary_accuracy: 1.0000 - val_loss: 1.7830e-05 - val_binary_accuracy: 1.0000

# %%
new_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 128, 128, 1)]     0
#
#  gray_to_rgb_norm (Gray2VGGI  (None, 128, 128, 3)      0
#  nput)
#
#  rescaling (Rescaling)       (None, 128, 128, 3)       0
#
#  inception_v3 (Functional)   (None, 2, 2, 2048)        21802784
#
#  global_max_pooling2d (Globa  (None, 2048)             0
#  lMaxPooling2D)
#
#  dense (Dense)               (None, 1)                 2049
#
# =================================================================
# Total params: 21,804,833
# Trainable params: 2,049
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
from keras.preprocessing.image import load_img, img_to_array
_img = load_img("./drive/MyDrive/z1/class_massive_10/63.jpg",target_size=(128,128))
plt.imshow(_img)
plt.show()

# %%
from keras.applications.inception_v3 import preprocess_input

# %%
v =tf.keras.utils.img_to_array(_img)

# %%
print(tf.shape(v))
# Out:
# tf.Tensor([128 128   3], shape=(3,), dtype=int32)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-c758ca6b4165> in <module>()
# ----> 1 g = tf.numpy(v)
#
# AttributeError: module 'tensorflow' has no attribute 'numpy'

# %%
def prep_input(path):
    image = tf.image.decode_png(tf.io.read_file(path))
    image = tf.expand_dims(image, axis=0)
    image = tf.cast(image, tf.float32)
    image = tf.image.resize(image, [128,128])
    return image

# %%
def norm_flat_image(img):
    grads_norm = img[:,:,0]+ img[:,:,1]+ img[:,:,2]
    grads_norm = (grads_norm - tf.reduce_min(grads_norm))/ (tf.reduce_max(grads_norm)- tf.reduce_min(grads_norm))
    return grads_norm

# %%
def plot_maps(img1, img2,vmin=0.3,vmax=0.7, mix_val=2):
    f = plt.figure(figsize=(15,45))
    plt.subplot(1,3,1)
    plt.imshow(img1,vmin=vmin, vmax=vmax, cmap="gray")
    plt.axis("off")
    plt.subplot(1,3,2)
    plt.imshow(img2, cmap = "gray")
    plt.axis("off")
    plt.subplot(1,3,3)
    plt.imshow(img1*mix_val+img2/mix_val, cmap = "gray" )
    plt.axis("off")

# %%
img_path= "./drive/MyDrive/z1/class_massive_10/63.jpg"

# %%
input_img = prep_input(img_path)

# %%
input_img = tf.keras.applications.densenet.preprocess_input(input_img)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-17-0e94942ea248> in <module>()
#       1
# ----> 2 input_img = tf.keras.applications.densenet.preprocess_input(input_img)
#
# /usr/local/lib/python3.7/dist-packages/keras/applications/densenet.py in preprocess_input(x, data_format)
#     364 def preprocess_input(x, data_format=None):
#     365   return imagenet_utils.preprocess_input(
# --> 366       x, data_format=data_format, mode='torch')
#     367
#     368
#
# /usr/local/lib/python3.7/dist-packages/keras/applications/imagenet_utils.py in preprocess_input(x, data_format, mode)
#     116   else:
#     117     return _preprocess_symbolic_input(
# --> 118         x, data_format=data_format, mode=mode)
#     119
#     120
#
# /usr/local/lib/python3.7/dist-packages/keras/applications/imagenet_utils.py in _preprocess_symbolic_input(x, data_format, mode)
#     287         x, backend.cast(mean_tensor, backend.dtype(x)), data_format=data_format)
#     288   else:
# --> 289     x = backend.bias_add(x, mean_tensor, data_format)
#     290   if std is not None:
#     291     std_tensor = backend.constant(np.array(std), dtype=backend.dtype(x))
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/keras/backend.py in bias_add(x, bias, data_format)
#    6322     if data_format == 'channels_first':
#    6323       return tf.nn.bias_add(x, bias, data_format='NCHW')
# -> 6324     return tf.nn.bias_add(x, bias, data_format='NHWC')
#    6325   if ndim(x) in (3, 4, 5):
#    6326     if data_format == 'channels_first':
#
# InvalidArgumentError: Must provide as many biases as the channel dimension of the input tensor: [3] vs. 1 in [1,128,128,1] [Op:BiasAdd]
