# %% [markdown]
# <a href="https://colab.research.google.com/github/VMBoehm/N3AS_Project_Malika/blob/main/2_Copy_of_First_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets as datasets
from sklearn import model_selection as ms
import matplotlib.pyplot as plt
import numpy as np

# %%
random_seed = 1534

# %%
## TASK: Play with different class_sep parameters, how does the model accuracy degrade/improve?
dataset = datasets.make_classification(n_samples=1000, n_features=4, random_state=random_seed, class_sep= 3)
## n_features = 5 does something weird, We talked about class_sep last monday.

# %%
features, labels = dataset
print(features.shape)
# Out:
# (1000, 4)

# %%
plt.scatter(features[:,0],features[:,1], c=labels)
plt.show()
plt.scatter(features[:,2],features[:,3], c=labels)
plt.show()

# %%
X_train, X_test, y_train, y_test = ms.train_test_split(features,labels, test_size = 0.2)

# %%
print('X_train:',np.shape(X_train))
print('y_train:',np.shape(y_train))
print('X_test:',np.shape(X_test))
print('y_test:',np.shape(y_test))
# Out:
# X_train: (800, 4)
# y_train: (800,)
# X_test: (200, 4)
# y_test: (200,)

# %%
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
basic_model = Sequential()

# %%
# Adding layers to the model
# First layers: 16 neurons/perceptrons that takes the input and uses Leaky ReLU activation function.

basic_model.add(Dense(units = 4 , activation = 'LeakyReLU', input_shape = (4,))) 
# Second layer: 1 neuron/perceptron that takes the input from the 1st layers and gives output as 0 or 1.Activation used is 'Hard Sigmoid'

# TASK: Can you change the output to be probabilistic (probability for each class) by using 'softmax' as an activation function?
#basic_model.add(Dense(1, activation = 'hard_sigmoid'))
### This is what I added. I think this is right.
basic_model.add(Dense(2, activation='softmax'))

# %%
# TASK optional): How does the Adam optimizer work? 
# from googling I have learned that the adam Optimizer is a Stochastic optimization. Which means its does graident optmaztion. I am acutally not really sure how it works
## I found this paper about it https://arxiv.org/pdf/1412.6980.pdf but its a little hard to understand.
## I know that basically it find how to get down hill the fastest
opt = keras.optimizers.Adam(learning_rate=0.01)
#TASK: What is binary cross entropy? What does it measure?
basic_model.compile(loss = 'sparse_categorical_crossentropy', optimizer = opt, metrics = ['accuracy'])
## the Binary cross entropy is ued for our loss paramter which calculates the degree of errror. A neural network measures doesn't measure 
# acurracy but instead loss. This is than used to measure accuracy. Binary_crossentropy is used when you have a binary system like cats or dogs or 1 and 0

# %%
# TASK: add validation data (https://keras.io/api/models/model_training_apis/)
basic_model.fit(X_train, y_train, epochs=50, validation_data= (X_test, y_test))
# Out:
# Epoch 1/50
# 25/25 [==============================] - 1s 16ms/step - loss: 1.1551 - accuracy: 0.3850 - val_loss: 0.5875 - val_accuracy: 0.6950
# Epoch 2/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4196 - accuracy: 0.9675 - val_loss: 0.2806 - val_accuracy: 1.0000
# Epoch 3/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1667 - accuracy: 1.0000 - val_loss: 0.0904 - val_accuracy: 1.0000
# Epoch 4/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0559 - accuracy: 1.0000 - val_loss: 0.0348 - val_accuracy: 1.0000
# Epoch 5/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0248 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 1.0000
# Epoch 6/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 1.0000
# Epoch 7/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 8/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 9/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 10/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 11/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 12/50
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 13/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 14/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 15/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 16/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 17/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 18/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 19/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 20/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 21/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 22/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 9.8181e-04 - val_accuracy: 1.0000
# Epoch 23/50
# 25/25 [==============================] - 0s 3ms/step - loss: 9.3377e-04 - accuracy: 1.0000 - val_loss: 9.0327e-04 - val_accuracy: 1.0000
# Epoch 24/50
# 25/25 [==============================] - 0s 3ms/step - loss: 8.6527e-04 - accuracy: 1.0000 - val_loss: 8.3359e-04 - val_accuracy: 1.0000
# Epoch 25/50
# 25/25 [==============================] - 0s 3ms/step - loss: 8.0190e-04 - accuracy: 1.0000 - val_loss: 7.6836e-04 - val_accuracy: 1.0000
# Epoch 26/50
# 25/25 [==============================] - 0s 3ms/step - loss: 7.4730e-04 - accuracy: 1.0000 - val_loss: 7.0905e-04 - val_accuracy: 1.0000
# Epoch 27/50
# 25/25 [==============================] - 0s 3ms/step - loss: 6.9604e-04 - accuracy: 1.0000 - val_loss: 6.6192e-04 - val_accuracy: 1.0000
# Epoch 28/50
# 25/25 [==============================] - 0s 3ms/step - loss: 6.5171e-04 - accuracy: 1.0000 - val_loss: 6.1844e-04 - val_accuracy: 1.0000
# Epoch 29/50
# 25/25 [==============================] - 0s 3ms/step - loss: 6.1141e-04 - accuracy: 1.0000 - val_loss: 5.7984e-04 - val_accuracy: 1.0000
# Epoch 30/50
# 25/25 [==============================] - 0s 3ms/step - loss: 5.7391e-04 - accuracy: 1.0000 - val_loss: 5.3994e-04 - val_accuracy: 1.0000
# Epoch 31/50
# 25/25 [==============================] - 0s 3ms/step - loss: 5.4016e-04 - accuracy: 1.0000 - val_loss: 5.0705e-04 - val_accuracy: 1.0000
# Epoch 32/50
# 25/25 [==============================] - 0s 3ms/step - loss: 5.1017e-04 - accuracy: 1.0000 - val_loss: 4.7461e-04 - val_accuracy: 1.0000
# Epoch 33/50
# 25/25 [==============================] - 0s 3ms/step - loss: 4.8123e-04 - accuracy: 1.0000 - val_loss: 4.5308e-04 - val_accuracy: 1.0000
# Epoch 34/50
# 25/25 [==============================] - 0s 3ms/step - loss: 4.5790e-04 - accuracy: 1.0000 - val_loss: 4.2145e-04 - val_accuracy: 1.0000
# Epoch 35/50
# 25/25 [==============================] - 0s 4ms/step - loss: 4.3183e-04 - accuracy: 1.0000 - val_loss: 3.9800e-04 - val_accuracy: 1.0000
# Epoch 36/50
# 25/25 [==============================] - 0s 3ms/step - loss: 4.0959e-04 - accuracy: 1.0000 - val_loss: 3.7907e-04 - val_accuracy: 1.0000
# Epoch 37/50
# 25/25 [==============================] - 0s 2ms/step - loss: 3.8940e-04 - accuracy: 1.0000 - val_loss: 3.5865e-04 - val_accuracy: 1.0000
# Epoch 38/50
# 25/25 [==============================] - 0s 3ms/step - loss: 3.7097e-04 - accuracy: 1.0000 - val_loss: 3.3925e-04 - val_accuracy: 1.0000
# Epoch 39/50
# 25/25 [==============================] - 0s 3ms/step - loss: 3.5317e-04 - accuracy: 1.0000 - val_loss: 3.2333e-04 - val_accuracy: 1.0000
# Epoch 40/50
# 25/25 [==============================] - 0s 3ms/step - loss: 3.3737e-04 - accuracy: 1.0000 - val_loss: 3.0518e-04 - val_accuracy: 1.0000
# Epoch 41/50
# 25/25 [==============================] - 0s 3ms/step - loss: 3.2173e-04 - accuracy: 1.0000 - val_loss: 2.9361e-04 - val_accuracy: 1.0000
# Epoch 42/50
# 25/25 [==============================] - 0s 3ms/step - loss: 3.0770e-04 - accuracy: 1.0000 - val_loss: 2.7722e-04 - val_accuracy: 1.0000
# Epoch 43/50
# 25/25 [==============================] - 0s 3ms/step - loss: 2.9395e-04 - accuracy: 1.0000 - val_loss: 2.6497e-04 - val_accuracy: 1.0000
# Epoch 44/50
# 25/25 [==============================] - 0s 3ms/step - loss: 2.8179e-04 - accuracy: 1.0000 - val_loss: 2.5320e-04 - val_accuracy: 1.0000
# Epoch 45/50
# 25/25 [==============================] - 0s 3ms/step - loss: 2.7026e-04 - accuracy: 1.0000 - val_loss: 2.4196e-04 - val_accuracy: 1.0000
# Epoch 46/50
# 25/25 [==============================] - 0s 3ms/step - loss: 2.5952e-04 - accuracy: 1.0000 - val_loss: 2.2998e-04 - val_accuracy: 1.0000
# Epoch 47/50
# 25/25 [==============================] - 0s 3ms/step - loss: 2.4861e-04 - accuracy: 1.0000 - val_loss: 2.2040e-04 - val_accuracy: 1.0000
# Epoch 48/50
# 25/25 [==============================] - 0s 3ms/step - loss: 2.3900e-04 - accuracy: 1.0000 - val_loss: 2.1088e-04 - val_accuracy: 1.0000
# Epoch 49/50
# 25/25 [==============================] - 0s 3ms/step - loss: 2.2986e-04 - accuracy: 1.0000 - val_loss: 2.0281e-04 - val_accuracy: 1.0000
# Epoch 50/50
# 25/25 [==============================] - 0s 3ms/step - loss: 2.2108e-04 - accuracy: 1.0000 - val_loss: 1.9444e-04 - val_accuracy: 1.0000

# %%
train_p=basic_model.predict(X_train)

# %%
loss_and_metrics = basic_model.evaluate(X_test, y_test)
print('Loss = ',loss_and_metrics[0])
print('Accuracy = ',loss_and_metrics[1])
# Out:
# 7/7 [==============================] - 0s 3ms/step - loss: 1.9444e-04 - accuracy: 1.0000
# Loss =  0.00019444206554908305
# Accuracy =  1.0

# %%
## calulating accuracy from scartch
## so this is a binary acuraccy calcuation
def accuracy_by_hand(X_true, X_train):
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-8954bb6f8e18> in <module>()
#       6                         correct += 1
#       7         return correct / float(len(actual)) * 100.0
# ----> 8 accuracy_metric(X_train, X_test)
#
# <ipython-input-19-8954bb6f8e18> in accuracy_metric(actual, predicted)
#       3         correct = 0
#       4         for i in range(len(actual)):
# ----> 5                 if actual[i] == predicted[i]:
#       6                         correct += 1
#       7         return correct / float(len(actual)) * 100.0
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
#TASK: create an ROC plot! compute AUROC
####This was very wrong but I wanted to keep it just in case.
import sklearn.metrics as metrics
from sklearn.metrics import roc_curve, auc
y_pred = basic_model.predict(X_test).ravel()
data_y = np.resize(y_test,(400))
nn_fpr_keras, nn_tpr_keras, nn_thresholds_keras = roc_curve(data_y, y_pred)
auc_keras = auc(nn_fpr_keras, nn_tpr_keras)
plt.plot(nn_fpr_keras, nn_tpr_keras, marker='.', label='Neural Network (auc = %0.3f)' % auc_keras)

# %%
## I used this Site https://www.dlology.com/blog/simple-guide-on-how-to-generate-roc-plot-for-keras-classifier/
from sklearn.metrics import roc_curve
data_x = np.resize(X_test,(400,4))
data_y = np.resize(y_test,(400))
y_pred_keras = basic_model.predict(X_test).ravel()
fpr_keras, tpr_keras, thresholds_keras = roc_curve(data_y, y_pred_keras)

from sklearn.metrics import auc
auc_keras = auc(fpr_keras, tpr_keras)

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(max_depth=3, n_estimators=10)
rf.fit(X_train, y_train)

y_pred_rf = rf.predict_proba(X_test)[:, 1]
fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test, y_pred_rf)
auc_rf = auc(fpr_rf, tpr_rf)

plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras, tpr_keras, label='Keras (area = {:.3f})'.format(auc_keras))
plt.plot(fpr_rf, tpr_rf, label='RF (area = {:.3f})'.format(auc_rf))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
# Zoom in view of the upper left corner.
plt.figure(2)
plt.xlim(0, 0.2)
plt.ylim(0.8, 1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras, tpr_keras, label='Keras (area = {:.3f})'.format(auc_keras))
plt.plot(fpr_rf, tpr_rf, label='RF (area = {:.3f})'.format(auc_rf))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve (zoomed in at top left)')
plt.legend(loc='best')
plt.show()
